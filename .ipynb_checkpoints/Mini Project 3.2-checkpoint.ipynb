# %% [markdown]
# # Customer Personality Analysis

# %% [markdown]
# ## Understanding and Cleaning the Dataset

# %%
#pip install wordcloud

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn import metrics

import chardet
from wordcloud import WordCloud
from datetime import datetime

# %%
#with open('training.1600000.processed.noemoticon.csv', 'rb') as f:
    #result = chardet.detect(f.read())
#print(result['encoding'])

# %%
# Loading the Dataset
labels=['target','ids','date','flag','user','text']
df = pd.read_csv('training.1600000.processed.noemoticon.csv',names=labels, encoding='Windows-1252')

# %%
df
# Out:
#          target         ids                          date      flag  \
# 0             0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1             0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2             0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3             0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4             0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...         ...         ...                           ...       ...
# 1599995       4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996       4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997       4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998       4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999       4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# 0        _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          scotthamilton  is upset that he can't update his Facebook by ...
# 2               mattycus  @Kenichan I dived many times for the ball. Man...
# 3                ElleCTF    my whole body feels itchy and like its on fire
# 4                 Karoli  @nationwideclass no, it's not behaving at all....
# ...                  ...                                                ...
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1600000 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   target  1600000 non-null  int64
#  1   ids     1600000 non-null  int64
#  2   date    1600000 non-null  object
#  3   flag    1600000 non-null  object
#  4   user    1600000 non-null  object
#  5   text    1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %%
# Identifying Null Values
df.isnull().sum()
# Out:
# target    0
# ids       0
# date      0
# flag      0
# user      0
# text      0
# dtype: int64

# %%
# Final Shape
print(df.shape)
# Out:
# (1600000, 6)

# %%
# Value counts for 'target'
tar_value = df['target'].value_counts()
print('Value Count for:\n')
print(tar_value)
# Out:
# Value Count for:
#
# target
# 0    800000
# 4    800000
# Name: count, dtype: int64

# %%
# Reducing the dataset to 20,000 rows maximum with equal amounts from 0 & 4
neg_rows = df[df['target'] == 0].head(10000)
pos_rows = df[df['target'] == 4].head(10000)

# Combine the two data
df_final = pd.concat([neg_rows, pos_rows], ignore_index=True)
df_final['target'].value_counts()
# Out:
# target
# 0    10000
# 4    10000
# Name: count, dtype: int64

# %%
df_final
# Out:
#        target         ids                          date      flag  \
# 0           0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1           0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2           0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3           0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4           0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...       ...         ...                           ...       ...
# 19995       4  1469642836  Tue Apr 07 06:59:39 PDT 2009  NO_QUERY
# 19996       4  1469642843  Tue Apr 07 06:59:39 PDT 2009  NO_QUERY
# 19997       4  1469642883  Tue Apr 07 06:59:40 PDT 2009  NO_QUERY
# 19998       4  1469643029  Tue Apr 07 06:59:42 PDT 2009  NO_QUERY
# 19999       4  1469643036  Tue Apr 07 06:59:42 PDT 2009  NO_QUERY
#
#                   user                                               text
# 0      _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1        scotthamilton  is upset that he can't update his Facebook by ...
# 2             mattycus  @Kenichan I dived many times for the ball. Man...
# 3              ElleCTF    my whole body feels itchy and like its on fire
# 4               Karoli  @nationwideclass no, it's not behaving at all....
# ...                ...                                                ...
# 19995     maricelarios  Morning! I have slacked for two days in twitte...
# 19996         Codepope  @bensummers Isn't that sweet of them.... Altru...
# 19997        christyku  @jakrose Um, milk *fathers* don't have udders....
# 19998        EdRoberts    @zenaweist They could also tweet @BeccaRoberts
# 19999       celeloriel  Good lord, I still have 125 work emails to cat...
#
# [20000 rows x 6 columns]

# %% [markdown]
# # Visualising the Data

# %%
# Bar plot of 'target' column
plt.figure(figsize=(10,6))
df_final['target'].value_counts().plot(kind='bar', color=['red', 'green'])
plt.title('Distribution of Targets')
plt.xlabel('Target')
plt.ylabel('Frequency')
plt.xticks(rotation=0)
plt.show()

# %%
# Word Clouds
fig, axes = plt.subplots(1, 2, figsize=(12,6))

titles = ['Word Cloud for Negative Target', 'Word Cloud for Positive Target'] 
for i, target in enumerate([0, 4]):
    subset = df_final[df_final['target'] == target]
    text = ''.join(subset['text'])
    wordcloud = WordCloud(width=400, height=300, background_color='white').generate(text)
    axes[i].imshow(wordcloud, interpolation='bilinear')
    axes[i].set_title(titles[i])
    axes[i].axis('off')

plt.show()

# %%
# Converting the timestamp to datetime format
df_final['date'] = pd.to_datetime(df['date'])

# Grouping by date and target
#df_final['date'] = df_final['date'].dt.date
target_counts = df_final.groupby([df_final['date'].dt.date, 'target']).size().unstack(fill_value=0)

# Plotting Target over time
plt.figure(figsize=(10,6))

# Plotting Negative target (Target = 0)
plt.plot(target_counts.index, target_counts[0], marker='o', linestyle='-', color='r', label='Negative Targets')

# Plotting Positive target (Target = 4)
plt.plot(target_counts.index, target_counts[4], marker='o', linestyle='-', color='g', label='Positive Targets')

plt.title('Target over Time')
plt.xlabel('Date')
plt.ylabel('Number of Tweets')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ahmad\AppData\Local\Temp\ipykernel_11020\2562411473.py:2: FutureWarning: Parsed string "Mon Apr 06 22:19:45 PDT 2009" included an un-recognized timezone "PDT". Dropping unrecognized timezones is deprecated; in a future version this will raise. Instead pass the string without the timezone, then use .tz_localize to convert to a recognized timezone.
#   df_final['date'] = pd.to_datetime(df['date'])

# %% [markdown]
# # Unsupervised Learning

# %% [markdown]
# ## Pipeline

# %% [markdown]
# ### Dimensionality Reduction (PCA) & Clustering (K-Means)

# %%
# Applying PCA
pca = PCA(n_components=2)
pca_result = pca.fit_transform(df_final)

# Convert to dataframe
df_pca = pd.DataFrame(pca_result, columns=['PCA1', 'PCA2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # Applying PCA
#       2 pca = PCA(n_components=2)
# ----> 3 pca_result = pca.fit_transform(df_scaled)
#       5 # Convert to dataframe
#       6 df_pca = pd.DataFrame(pca_result, columns=['PCA1', 'PCA2'])
#
# NameError: name 'df_scaled' is not defined

# %% [markdown]
# ## Clustering (K-Means)

# %%
# Apply K-Means clustering to the PCA Results
kmeans = KMeans(n_clusters=4, random_state=42)
clusters = kmeans.fit_predict(df_pca)

# Adding cluster labels to the PCA DataFrame
df_pca['Cluster'] = clusters

# %% [markdown]
# ## Visualising the Unsupervised Learning data

# %%
# Visualising
plt.figure(figsize=(10, 6))
sns.scatterplot(x='PCA1', y='PCA2', hue='Cluster', data=df_pca, palette='viridis')
plt.title('Clusters of Customers after PCA')
plt.show()
